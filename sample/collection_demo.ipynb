# %%
# import packages
import Exonodo

# %% [markdown]
# In this demo, the program will load config_arc.json and to collect the metal hydrides database information.
# The information will be saved in the file demo.json in the current folder.

# %%
# call the load_config() function to collection of metal hydrides
Exonodo.load_config('config_arc.json')
# Out:
# collecting 26Al1H
# db: AlHambra
# collecting 27Al1H
# db: AlHambra
# db: xsec-AlHambra
# collecting 27Al2H
# db: AlHambra
# db: xsec-AlHambra
# collecting 9Be1H
# db: Yadin-BeH
# db: Darby-Lewis
# db: xsec-Darby
# collecting 9Be2H
# db: Darby-Lewis
# collecting 9Be3H
# db: Darby-Lewis
# collecting 40Ca1H
# db: MoLLIST
# db: UGAMOP
# db: Yadin
# collecting 52Cr1H
# db: MoLLIST
# db: xsec-MoLLIST
# collecting 56Fe1H
# db: MoLLIST
# db: xsec-MoLLIST
# db: Bernath
# db: CDRR
# collecting 7Li1H
# db: xsec-CLT
# db: CLT
# collecting 24Mg1H
# db: MoLLIST
# db: UGAMOP
# db: Yadin
# collecting 25Mg1H
# db: Yadin
# collecting 26Mg1H
# db: Yadin
# collecting 23Na1H
# db: Rivlin
# collecting 23Na2H
# db: Rivlin
# collecting 58Ni1H
# db: HRV
# collecting 60Ni1H
# db: HRV
# collecting 62Ni1H
# db: HRV
# collecting 45Sc1H
# db: LYT
# db: xsec-LYT
# collecting 48Ti1H
# db: MoLLIST
# db: xsec-MoLLIST
# the collected data, ./demo.json, has been verified to be correct by exomol.all

# %% [markdown]
# The collection process will print each molecular data which has been successfully collected.
# At the end of collection, the data will be verified with the exomo.add..

# %%
import json
info = json.load(open('./demo.json', 'r'))
print(info)
# Out:
# {'metal hydrides': {'AlH': {'url': 'https://exomol.com/data/molecules/AlH', '26Al1H': {'url': 'https://exomol.com/data/molecules/AlH/26Al-1H', 'AlHambra': {'url': 'https://exomol.com/data/molecules/AlH/26Al-1H/AlHambra', 'recommended': True, 'data': {'Definitions file': {'url': 'https://exomol.com/db/AlH/26Al-1H/AlHambra/26Al-1H__AlHambra.def'}, 'Spectroscopic Model': {'url': 'https://exomol.com/models/AlH/26Al-1H/AlHambra/'}, 'AlHambra: line list': {'description': 'The AlHambra calculated line list for AlH (X and A states)', 'references': ['Yurchenko, S. N., Williams, H., Leyland, P. C., Lodi, L., Tennyson, J., "ExoMol linelists XXVIII: the rovibronic spectrum of AlH", Monthly Notices of the Royal Astronomical Society 479, 1401-1411 (2018). [https://doi.org/10.1093/mnras/sty1524][18YuWiLe.AlH]'], 'files': [{'file_name': '26Al-1H__AlHambra.trans.bz2', 'description': 'Frequency ordered transitions of (26Al)(1H)', 'url': 'https://exomol.com/db/AlH/26Al-1H/AlHambra/26Al-1H__AlHambra.tra
# ...
